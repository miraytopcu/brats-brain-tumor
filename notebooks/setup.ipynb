# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Bu dosya projenin başındaki gerekli kurulumları yapmanız için oluşturulmuştur. Lütfen aşağıdaki adımlardan sizin için uygun olanları takip ediniz.

# %% [markdown]
# # ***Paylaşılan Drive Linki ile Veri Setine Bağlanmak***
#
# Eğer sizinle verinin bulunduğu drive linki paylaşıldıysa aşağıdaki işlemleri uygulayabilirsiniz.

# %% [markdown]
# Kendi Drive'ınıza girip "Benimle Paylaşılanlar" kısmında bu klasörü görmelisiniz.
#
# Klasörün üzerine sağ tıklayıp "Drive'a kısayol ekle" demelisiniz.

# %%
from google.colab import drive
drive.mount('/content/drive')

# Çıkan uyarıda "Google Drive'a Bağlan" de ve hesabını seç. Sol taraftaki dosya simgesine tıkladığında drive klasörünü görmen gerekiyor.
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = "/content/drive/MyDrive/BraTS_Project/data"

# %% [markdown]
# # ***Kaggle API ile Veriyi Çekmek***
#
# Eğer sizinle bir drive linki paylaşılmadıysa kaggle üzerinden veriyi kendi drivenıza aşağıdaki kodlarla yükleyebilirsiniz.
#
# Not: Veriyi çekmek için kişisel kaggle.json dosyanıza ihtiyaç vardır.
# - [kaggle.com](https://www.kaggle.com/) giriş yapın.
# - Sağ üstteki profil resmine tıkla > Settings'e gir.
# - Sayfayı aşağı kaydır, "API" bölümünü bul.
# - "Create New Token" butonuna bas.

# %% [markdown]
# 1.Adım: Google Drive Hazırlığı
# - Google Drive'ını aç.
#
# - Boş bir yere sağ tıkla > Yeni Klasör > Adı: BraTS_Project.
#
# - Bu klasörün içine gir. Tekrar sağ tıkla > Yeni Klasör > Adı: data.
# (Şu an Drive'da BraTS_Project/data yolun hazır.)

# %%
from google.colab import drive
drive.mount('/content/drive')

# Çıkan uyarıda "Google Drive'a Bağlan" de ve hesabını seç. Sol taraftaki dosya simgesine tıkladığında drive klasörünü görmen gerekiyor.

# %%
from google.colab import files
files.upload() # Buraya basınca dosya seçmeni isteyecek, o indirdiğin kaggle.json'u seç.

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %cd /content/drive/MyDrive/BraTS_Project/data

# !kaggle datasets download -d awsaf49/brats20-dataset-training-validation
# !unzip -q brats20-dataset-training-validation.zip

# %% [markdown]
# # ***GitHub Bağlantısını Yapmak***

# %%
# %cd /content/drive/MyDrive/BraTS_Project

# !git clone https://github.com/miraytopcu/brats-brain-tumor.git

# %%
# !pip install -q nibabel nilearn SimpleITK
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 107.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 MB 22.0 MB/s eta 0:00:00
